# %%
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import decode_predictions
from keras.models import Model, load_model
import keras.backend as K

import model as tcav_model
import tcav as tcav
import utils as utils
import activation_generator as act_gen
import tensorflow as tf
import utils_plot as utils_plot


from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from numpy.linalg import norm

import pickle
#from bunch import bunchify

import cav as cav

from os import listdir
from os.path import isfile, join
import operator
from PIL import Image
from keras.preprocessing import image

import os

import PIL.Image
from sklearn.metrics import pairwise
# Out:
# /data/anaconda/envs/py35/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = None
model = load_model('v3_model.h5')
# Out:
# WARNING:tensorflow:From /data/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /data/anaconda/envs/py35/lib/python3.5/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
sess = K.get_session()

endpoints_v3 = dict(
    input=model.inputs[0].name,
    input_tensor=model.inputs[0],
    logit=model.outputs[0].name,
    prediction=model.outputs[0].name,
    prediction_tensor=model.outputs[0],
)

tf.logging.set_verbosity(0)

working_dir = '/home/tyler/Desktop/tcav_on_azure'

label_path = os.path.join(working_dir,'labels.txt')

mymodel = tcav_model.KerasModelWrapper(sess, 
        label_path, [299, 299, 3], endpoints_v3, 
        'InceptionV3_public', (-1, 1))
# Out:
# WARNING:tensorflow:From /data/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
## Run specific CAV
hparams = tf.contrib.training.HParams(model_type='logistic', alpha=.1)

bottleneck = bottlenecks[0]
target_class = target
concepts = ['striped_sub_1', 'random500_0']

act_generator = act_gen.ImageActivationGenerator(mymodel, source_dir, activation_dir, max_examples=50)
acts = act_generator.process_and_load_activations([bottleneck], concepts + [target_class])

cav.get_or_train_cav(concepts,bottleneck,acts,cav_hparams=hparams,cav_dir='cavs')
# Out:
# ['striped_sub_1', 'random500_0', 'zebra']
# /data/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
#working_dir = '/Users/tyler/Desktop/dissertation/programming/tcav'
working_dir = '/home/tyler/Desktop/tcav_on_azure'

activation_dir =  working_dir + '/activations/'
cav_dir = working_dir + '/cavs/'
source_dir = working_dir + '/concepts/'

target = 'suit'

concepts = ['banded_sub_1']   

#'mixed0','mixed1', 'mixed2', 'mixed3', 'mixed4', 'mixed5', 'mixed6', 'mixed7', 'mixed8', 'mixed9_0', 'mixed9', 'mixed9_1', 'mixed10'

bottlenecks = ['mixed9']

alphas = [0.1]

# %%
act_generator = act_gen.ImageActivationGenerator(mymodel, source_dir, activation_dir, max_examples=50)

tf.logging.set_verbosity(1)

num_random = 2

mytcav = tcav.TCAV(sess,
        target, concepts, bottlenecks,
        act_generator, alphas,
        cav_dir = cav_dir,
        num_random_exp=num_random)
# Out:
# INFO:tensorflow:mixed9 ['banded_sub_1', 'random500_0'] suit 0.1
# INFO:tensorflow:mixed9 ['banded_sub_1', 'random500_1'] suit 0.1
# INFO:tensorflow:mixed9 ['random500_0', 'random500_1'] suit 0.1
# INFO:tensorflow:mixed9 ['random500_1', 'random500_0'] suit 0.1
# INFO:tensorflow:TCAV will 4 params

# %%
results = mytcav.run(run_parallel=True)
# Out:
# INFO:tensorflow:running 4 params
# INFO:tensorflow:running suit ['banded_sub_1', 'random500_0']
# INFO:tensorflow:running suit ['banded_sub_1', 'random500_1']
# INFO:tensorflow:running suit ['random500_0', 'random500_1']
# ['banded_sub_1', 'random500_1', 'suit']
# ['banded_sub_1', 'random500_0', 'suit']
# INFO:tensorflow:running suit ['random500_1', 'random500_0']
# ['random500_0', 'random500_1', 'suit']
# ['random500_1', 'random500_0', 'suit']
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_random500_1_mixed9 shape (50, 8, 8, 2048)
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_random500_0_mixed9 shape (50, 8, 8, 2048)
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_random500_0_mixed9 shape (50, 8, 8, 2048)
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_random500_1_mixed9 shape (50, 8, 8, 2048)
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_suit_mixed9 shape (50, 8, 8, 2048)
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_suit_mixed9 shape (50, 8, 8, 2048)
# Level 1:tensorflow:Registering Batch (<function _BatchGrad at 0x7f6fac75e0d0>) in gradient.
# Level 1:tensorflow:Registering Unbatch (<function _UnbatchGrad at 0x7f6fac6f5b70>) in gradient.
# Level 1:tensorflow:Registering BigQueryReader (None) in gradient.
# Level 1:tensorflow:Registering BigtableClient (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering BigtableLookupDataset (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering BigtablePrefixKeyDataset (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering BigtableRangeKeyDataset (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering BigtableSampleKeyPairsDataset (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering BigtableSampleKeysDataset (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering BigtableScanDataset (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering BigtableTable (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering DatasetToBigtable (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering PmfToQuantizedCdf (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RangeDecode (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RangeEncode (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering GRUBlockCell (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering GRUBlockCellGrad (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering GRUBlockCell (<function _GRUBlockCellGrad at 0x7f6fac695730>) in gradient.
# Level 1:tensorflow:Registering BlockLSTM (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering BlockLSTMGrad (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LSTMBlockCell (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LSTMBlockCellGrad (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LSTMBlockCell (<function _LSTMBlockCellGrad at 0x7f6fac622510>) in gradient.
# Level 1:tensorflow:Registering BlockLSTM (<function _BlockLSTMGrad at 0x7f6fac62e8c8>) in gradient.
# Level 1:tensorflow:Registering ZeroInitializer (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ZeroVarInitializer (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering SparseFeatureCross (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering SparseFeatureCrossV2 (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering SparseFeatureCross (None) in gradient.
# Level 1:tensorflow:Registering SparseFeatureCrossV2 (None) in gradient.
# Level 1:tensorflow:Registering GDNLowerBound (<function GDN._lower_bound_grad at 0x7f6fac242a60>) in gradient.
# Level 1:tensorflow:Registering AllToAll (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering CollectivePermute (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ConfigureDistributedTPU (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering CrossReplicaSum (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering EnqueueTPUEmbeddingIntegerBatch (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering EnqueueTPUEmbeddingSparseBatch (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering EnqueueTPUEmbeddingSparseTensorBatch (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering InfeedDequeue (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering InfeedDequeueTuple (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering InfeedEnqueue (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering InfeedEnqueueTuple (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingADAMParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingADAMParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingAdadeltaParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingAdadeltaParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingAdagradParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingAdagradParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingCenteredRMSPropParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingFTRLParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingFTRLParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingMDLAdagradLightParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingMomentumParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingMomentumParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingProximalAdagradParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingProximalAdagradParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingRMSPropParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingRMSPropParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering LoadTPUEmbeddingStochasticGradientDescentParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering OutfeedDequeue (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering OutfeedDequeueTuple (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering OutfeedEnqueue (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering OutfeedEnqueueTuple (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RecvTPUEmbeddingActivations (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingADAMParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingADAMParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingAdadeltaParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingAdadeltaParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingAdagradParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingAdagradParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingCenteredRMSPropParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingFTRLParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingFTRLParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingMDLAdagradLightParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingMomentumParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingMomentumParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingProximalAdagradParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingProximalAdagradParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingRMSPropParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingRMSPropParametersGradAccumDebug (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RetrieveTPUEmbeddingStochasticGradientDescentParameters (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering SendTPUEmbeddingGradients (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ShutdownDistributedTPU (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TPUCompilationResult (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TPUEmbeddingActivations (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TPUReplicate (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TPUReplicateMetadata (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TPUReplicatedInput (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TPUReplicatedOutput (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering WorkerHeartbeat (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering _XlaSendFromHost (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering _XlaRecvAtHost (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering _ConfigureDistributedTPU (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering _WaitForDistributedTPU (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering _SetGlobalTPUArray (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering _ShutdownDistributedTPU (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering _InitializeHostForDistributedTPU (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering _DisconnectHostFromDistributedTPUSystem (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering AllToAll (<function _all_to_all_grad at 0x7f6f662518c8>) in gradient.
# Level 1:tensorflow:Registering CollectivePermute (<function _collective_permute_grad at 0x7f6f66251950>) in gradient.
# Level 1:tensorflow:Registering CrossReplicaSum (<function _cross_replica_sum_grad at 0x7f6fac15bea0>) in gradient.
# Level 1:tensorflow:Registering XlaClusterOutput (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering XlaLaunch (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering XlaClusterOutput (<function _XlaClusterOutputGrad at 0x7f6fac08b730>) in gradient.
# Level 1:tensorflow:Registering hparams ((<class 'tensorflow.contrib.training.python.training.hparam_pb2.HParamDef'>, <function HParams.to_proto at 0x7f6f663409d8>, <function HParams.from_proto at 0x7f6f66340a60>)) in proto functions.
# Level 1:tensorflow:Registering tpu_estimator_iterations_per_loop ((<class 'tensorflow.core.framework.variable_pb2.VariableDef'>, <function _to_proto_fn at 0x7f704ffaba60>, <function _from_proto_fn at 0x7f704f9c4d90>)) in proto functions.
# Level 1:tensorflow:Registering ObtainNext (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering KMC2ChainInitialization (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering KmeansPlusPlusInitialization (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering NearestNeighbors (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering MaskedMatmul (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering WALSComputePartialLhsAndRhs (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering AdjustHsvInYiq (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering BipartiteMatch (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ImageConnectedComponents (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ImageProjectiveTransform (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ImageProjectiveTransformV2 (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ImageConnectedComponents (<function call_cpp_shape_fn at 0x7f70503d1f28>) in shape functions.
# Level 1:tensorflow:Registering ImageProjectiveTransform (<function call_cpp_shape_fn at 0x7f70503d1f28>) in shape functions.
# Level 1:tensorflow:Registering ImageProjectiveTransformV2 (<function call_cpp_shape_fn at 0x7f70503d1f28>) in shape functions.
# Level 1:tensorflow:Registering ImageProjectiveTransformV2 (<function _image_projective_transform_grad at 0x7f6f5532df28>) in gradient.
# Level 1:tensorflow:Registering BipartiteMatch (None) in gradient.
# Level 1:tensorflow:Registering ImageConnectedComponents (None) in gradient.
# Level 1:tensorflow:Registering SingleImageRandomDotStereograms (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering SingleImageRandomDotStereograms (None) in gradient.
# Level 1:tensorflow:Registering BytesInUse (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering BytesLimit (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering MaxBytesInUse (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering PeriodicResample (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering PeriodicResampleOpGrad (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering PeriodicResample (<function _periodic_resample_grad_cc at 0x7f6f543eff28>) in gradient.
# Level 1:tensorflow:Registering DecodeProtoV2 (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering DecodeProtoV2 (None) in gradient.
# Level 1:tensorflow:Registering EncodeProto (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering EncodeProto (None) in gradient.
# Level 1:tensorflow:Registering FoldFusedBatchNormGrad (<function _FoldFusedBatchNormGrad at 0x7f6f54100d08>) in gradient.
# Level 1:tensorflow:Registering Resampler (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ResamplerGrad (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering Resampler (<function _resampler_grad at 0x7f6f54128400>) in gradient.
# Level 1:tensorflow:Registering ResamplerGrad (None) in gradient.
# Level 1:tensorflow:Registering Rpc (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TryRpc (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering Rpc (None) in gradient.
# Level 1:tensorflow:Registering TryRpc (None) in gradient.
# Level 1:tensorflow:Registering GatherTree (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ReinterpretStringToFloat (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ScatterAddNdim (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering CreateTreeVariable (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering DecisionTreeResourceHandleOp (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering FeatureUsageCounts (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TraverseTreeV4 (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TreeDeserialize (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TreeIsInitializedOp (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TreePredictionsV4 (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TreeSerialize (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TreeSize (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering UpdateModelV4 (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering TreeVariable (None) in gradient.
# Level 1:tensorflow:Registering TreeSerialize (None) in gradient.
# Level 1:tensorflow:Registering TreeDeserialize (None) in gradient.
# Level 1:tensorflow:Registering TreeSize (None) in gradient.
# Level 1:tensorflow:Registering TreePredictionsV4 (None) in gradient.
# Level 1:tensorflow:Registering FeatureUsageCounts (None) in gradient.
# Level 1:tensorflow:Registering CreateFertileStatsVariable (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering FertileStatsDeserialize (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering FertileStatsIsInitializedOp (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering FertileStatsResourceHandleOp (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering FertileStatsSerialize (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering FinalizeTree (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering GrowTreeV4 (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering ProcessInputV4 (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering FertileStatsVariable (None) in gradient.
# Level 1:tensorflow:Registering FertileStatsSerialize (None) in gradient.
# Level 1:tensorflow:Registering FertileStatsDeserialize (None) in gradient.
# Level 1:tensorflow:Registering GrowTreeV4 (None) in gradient.
# Level 1:tensorflow:Registering ProcessInputV4 (None) in gradient.
# Level 1:tensorflow:Registering FinalizeTree (None) in gradient.
# Level 1:tensorflow:Registering RemoteFusedGraphExecute (<function _set_call_cpp_shape_fn.<locals>.call_without_requiring at 0x7f70503d60d0>) in default shape functions.
# Level 1:tensorflow:Registering RemoteFusedGraphExecute (None) in gradient.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
#
# INFO:tensorflow:CAV already exists: /home/tyler/Desktop/tcav_on_azure/cavs/random500_1-random500_0-mixed9-linear-0.1.pkl
# INFO:tensorflow:CAV already exists: /home/tyler/Desktop/tcav_on_azure/cavs/random500_0-random500_1-mixed9-linear-0.1.pkl
# INFO:tensorflow:/home/tyler/Desktop/tcav_on_azure/activations/acts_banded_sub_1_mixed9 does not exist, Making one...
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_random500_1_mixed9 shape (50, 8, 8, 2048)
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_suit_mixed9 shape (50, 8, 8, 2048)
# INFO:tensorflow:Training CAV ['banded_sub_1', 'random500_1'] - mixed9 alpha 0.1
# INFO:tensorflow:training with alpha=0.1
# INFO:tensorflow:using new version
# /data/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/linear_model/stochastic_gradient.py:144: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# INFO:tensorflow:acc per class {'random500_1': 1.0, 'overall': 0.9696969696969697, 'banded_sub_1': 0.9375}
# INFO:tensorflow:/home/tyler/Desktop/tcav_on_azure/cavs/banded_sub_1-random500_1-mixed9-linear-0.1_test.pkl
# INFO:tensorflow:did save save_path_lin_sep
# INFO:tensorflow:/home/tyler/Desktop/tcav_on_azure/activations/acts_banded_sub_1_mixed9 does not exist, Making one...
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_random500_0_mixed9 shape (50, 8, 8, 2048)
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_suit_mixed9 shape (50, 8, 8, 2048)
# INFO:tensorflow:Training CAV ['banded_sub_1', 'random500_0'] - mixed9 alpha 0.1
# INFO:tensorflow:training with alpha=0.1
# INFO:tensorflow:using new version
# /data/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/linear_model/stochastic_gradient.py:144: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# INFO:tensorflow:acc per class {'random500_0': 0.9411764705882353, 'overall': 0.9696969696969697, 'banded_sub_1': 1.0}
# INFO:tensorflow:/home/tyler/Desktop/tcav_on_azure/cavs/banded_sub_1-random500_0-mixed9-linear-0.1_test.pkl
# INFO:tensorflow:did save save_path_lin_sep
# INFO:tensorflow:Done running 4 params. Took 35.25985360145569 seconds...

# %% [markdown]
# ## Load CAV

# %%
working_dir = '/home/tyler/Desktop/tcav_on_azure'

class_1 = 'banded_sub_1'
class_2 = 'random500_0'
layer = 'mixed9'
lm_type = 'linear'

cav_name = class_1 + '-' + class_2 + '-' + layer + '-' + lm_type + '-0.1'
sub_path = 'cavs/' + cav_name + '.pkl'


path = os.path.join(working_dir, sub_path)

this_cav = cav.CAV.load_cav(path)

# %%
this_cav.concepts
# Out:
# ['banded_sub_1', 'random500_0']

# %% [markdown]
# ## Generate Activations

# %%
bottleneck = bottlenecks[0]
target_class = target

target_class,concepts = 'suit', ['banded_sub_1']
#my_class,concept = 'zebra','striped_sub_1'

acts = act_generator.process_and_load_activations([bottleneck], concepts + [target_class])


act_class = acts[target_class][bottleneck]
act_concept = acts[concepts[0]][bottleneck]
# Out:
# ['banded_sub_1', 'suit']
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_banded_sub_1_mixed9 shape (50, 8, 8, 2048)
# INFO:tensorflow:Loaded /home/tyler/Desktop/tcav_on_azure/activations/acts_suit_mixed9 shape (50, 8, 8, 2048)

# %%
acts.keys()
# Out:
# dict_keys(['suit', 'banded_sub_1'])

# %%
len(acts[target_class][bottleneck])
# Out:
# 50

# %%
# cosine similarity
import math
def cosine_similarity(v1,v2):
    # compute cosine similarity of v1 to v2: (v1 dot v2)/{||v1||*||v2||)
    sumxx, sumxy, sumyy = 0, 0, 0
    for i in range(len(v1)):
        x = v1[i]; y = v2[i]
        sumxx += x*x
        sumyy += y*y
        sumxy += x*y
    return sumxy / math.sqrt(sumxx*sumyy)

# %%
# image list
path = 'activations/images_used_' + my_class + '.pkl'
with open(path, 'rb') as f:
    data = pickle.load(f)
    
image_list = data

# %%
# make dict
ranked = {}

#concept = 'striped_sub_2'

# define cavs
striped_cav = this_cav.cavs[0]
striped_cav_2d = striped_cav.reshape(-1,1)

# image_list
for count, each in enumerate(image_list):
    
    demo_1 = acts[concept][bottleneck][count]
    demo_2d = demo_1.reshape(-1,1)
    
    cos = cosine_similarity(striped_cav_2d,demo_2d)
    
    ranked[each] = cos

# %%
## rank images
sorted_rank = sorted(ranked.items(), key=operator.itemgetter(1),reverse=True)

# %%
## show image
rank = 0

img_path, cos = sorted_rank[rank]
img = image.load_img(img_path, target_size=(299, 299))
#img

# %%
import matplotlib.pyplot as plt

w, h = 120, 120
fig = plt.figure(figsize=(15, 8))
columns, rows = 5, 1

start = 1

for i in range(1, columns*rows + 1):
    img_path, cos = sorted_rank[start + i - 2]
    img = image.load_img(img_path, target_size=(299, 299))
    fig.add_subplot(rows, columns, i)
    plt.title(round(cos[0],4))
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
#sorted_rank

# %% [markdown]
# ## Get Activations

# %%
# image list
my_class = 'zebra'
path = 'activations/images_used_' + my_class + '.pkl'
with open(path, 'rb') as f:
    data = pickle.load(f)
    
image_list = data

# %%
#image_list

# %%
## loop through files

cav_1 = this_cav.cavs[0]
cav_1 = cav_1.reshape(-1,1)

new_rank = {}

#for img_path, cos_sim in sorted_rank:
for img_path in image_list:
    filename = img_path

    img = np.array(PIL.Image.open(tf.gfile.Open(filename, 'rb')).convert('RGB').resize((299,299), PIL.Image.BILINEAR))
    img = np.float32(img) / 255.0
    
    acts_1 = mymodel.run_examples([img], 'mixed9')
    acts_shaped =  mymodel.reshape_activations(acts_1).squeeze()
    acts_shaped = acts_shaped.reshape(-1,1)
    cos = cosine_similarity(cav_1,acts_shaped)
    new_rank[img_path] = cos

# %%
new_sorted_rank = sorted(new_rank.items(), key=operator.itemgetter(1),reverse=True)

# %%
import matplotlib.pyplot as plt

w, h = 120, 120
fig = plt.figure(figsize=(15, 8))
columns, rows = 5, 2

start = 1

for i in range(1, columns*rows +1):
    img_path, cos = new_sorted_rank[start + i - 2]
    img = image.load_img(img_path, target_size=(299, 299))
    fig.add_subplot(rows, columns, i)
    plt.title(round(cos[0],4))
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
## perturb

# %%
for img_path in image_list:
    filename = img_path

    img = np.array(PIL.Image.open(tf.gfile.Open(filename, 'rb')).convert('RGB').resize(shape, PIL.Image.BILINEAR))
    img = np.float32(img) / 255.0
    
    acts_1 = mymodel.run_examples([img], 'mixed10')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-2094891938cf> in <module>()
#       2     filename = img_path
#       3
# ----> 4     img = np.array(PIL.Image.open(tf.gfile.Open(filename, 'rb')).convert('RGB').resize(shape, PIL.Image.BILINEAR))
#       5     img = np.float32(img) / 255.0
#       6
#
# NameError: name 'shape' is not defined

# %%
acts_1[0][0][0]
# Out:
# array([0.        , 0.        , 0.        , ..., 0.29479256, 0.        ,
#        0.        ], dtype=float32)

# %%
perturbed_act = this_cav.perturb_act(acts_1,'striped_sub_2')

# %%
perturbed_act[0][0][0]
# Out:
# array([ 0.08471466, -0.08600735,  0.0034667 , ...,  0.44867757,
#         0.04259563, -0.02487374])

# %%
mymodel.get_predictions()

# %%
sess = K.get_session()

endpoints_v3 = dict(
    input=model.inputs[0].name,
    input_tensor=model.inputs[0],
    logit=model.outputs[0].name,
    prediction=model.outputs[0].name,
    prediction_tensor=model.outputs[0],
)

tf.logging.set_verbosity(0)

working_dir = '/home/tyler/Desktop/tcav_on_azure'

label_path = os.path.join(working_dir,'labels.txt')

mymodel = tcav_model.KerasModelWrapper(sess, 
        label_path, [299, 299, 3], endpoints_v3, 
        'InceptionV3_public', (-1, 1))

# %%
#model.summary()

# %%
len(model.layers)
# Out:
# 313

# %%
mixed_10 = model.layers[310]
mixed_10.get_input_at(0)
# Out:
# [<tf.Tensor 'activation_86/Relu:0' shape=(?, 8, 8, 320) dtype=float32>,
#  <tf.Tensor 'mixed9_1/concat:0' shape=(?, 8, 8, 768) dtype=float32>,
#  <tf.Tensor 'concatenate_2/concat:0' shape=(?, 8, 8, 768) dtype=float32>,
#  <tf.Tensor 'activation_94/Relu:0' shape=(?, 8, 8, 192) dtype=float32>]

# %%
new_endpoints = dict(
    #input=model.inputs[0].name,
    input=mixed_10.name,
    input_tensor=mixed_10.input,
    logit=model.outputs[0].name,
    prediction=model.outputs[0].name,
    prediction_tensor=model.outputs[0],
)

tf.logging.set_verbosity(0)

working_dir = '/home/tyler/Desktop/tcav_on_azure'

label_path = os.path.join(working_dir,'labels.txt')

new_model = tcav_model.KerasModelWrapper(sess, 
        label_path, [299, 299, 3], new_endpoints, 
        'InceptionV3_public', (-1, 1))

# %%
type(perturbed_act)
# Out:
# numpy.ndarray

# %%
new_model.ends
# Out:
# {'input': [<tf.Tensor 'activation_86/Relu:0' shape=(?, 8, 8, 320) dtype=float32>,
#   <tf.Tensor 'mixed9_1/concat:0' shape=(?, 8, 8, 768) dtype=float32>,
#   <tf.Tensor 'concatenate_2/concat:0' shape=(?, 8, 8, 768) dtype=float32>,
#   <tf.Tensor 'activation_94/Relu:0' shape=(?, 8, 8, 192) dtype=float32>],
#  'prediction': <tf.Tensor 'predictions/Softmax:0' shape=(?, 1000) dtype=float32>}

# %%
mixed_10.input
# Out:
# [<tf.Tensor 'activation_86/Relu:0' shape=(?, 8, 8, 320) dtype=float32>,
#  <tf.Tensor 'mixed9_1/concat:0' shape=(?, 8, 8, 768) dtype=float32>,
#  <tf.Tensor 'concatenate_2/concat:0' shape=(?, 8, 8, 768) dtype=float32>,
#  <tf.Tensor 'activation_94/Relu:0' shape=(?, 8, 8, 192) dtype=float32>]

# %%
model.inputs[0]
# Out:
# <tf.Tensor 'input_1:0' shape=(?, 299, 299, 3) dtype=float32>

# %%
import matplotlib.pyplot as plt

w, h = 120, 120
fig = plt.figure(figsize=(15, 8))
columns, rows = 5, 2

start = 40

for i in range(1, columns*rows +1):
    img_path, cos = new_sorted_rank[start + i - 2]
    img = image.load_img(img_path, target_size=(299, 299))
    fig.add_subplot(rows, columns, i)
    plt.title(round(cos[0],4))
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
to_mixed_9 = model.layers[279]
to_mixed_9.output.name
# Out:
# 'mixed9/concat:0'

# %%
## first_part

to_mixed_9 = model.layers[279]
to_mixed_9.get_input_at(0)

mixed_9 = model.layers[280]
mixed_9.get_input_at(0)

first_part_endpoints = dict(
    input=model.inputs[0].name,
    input_tensor=model.inputs[0],
    logit=to_mixed_9.output[0].name,
    prediction=to_mixed_9.output[0].name,
    prediction_tensor=to_mixed_9.output[0],
)

first_part_model = tcav_model.KerasModelWrapper(sess, 
        label_path, [299, 299, 3], first_part_endpoints, 
        'InceptionV3_public', (-1, 1))

# %%
pred_1 = first_part_model.get_predictions(x)

# %%
## second_part
mixed_9 = model.layers[280]
mixed_9.get_input_at(0)

second_part_endpoints = dict(
    input=mixed_9.name,
    input_tensor=mixed_9.input,
    logit=model.outputs[0].name,
    prediction=model.outputs[0].name,
    prediction_tensor=model.outputs[0],
)


second_part_model = tcav_model.KerasModelWrapper(sess, 
        label_path, [299, 299, 3], second_part_endpoints, 
        'InceptionV3_public', (-1, 1))

# %%
# perturb
img = image.load_img(img_path, target_size=(299, 299))
img_array = np.array(img)
img_new_dims = np.expand_dims(img_array, axis=0)
img_input = preprocess_input(img_new_dims)

pred_1 = first_part_model.get_predictions(img_input)
pred_1 = np.expand_dims(pred_1, axis=0)

pred_1_pert = this_cav.perturb_act(pred_1,'striped_sub_1',alpha = 5)

pred_2 = second_part_model.get_predictions(pred_1_pert)
decode_predictions(pred_2, top=5)
# Out:
# [[('n02389026', 'sorrel', 0.5091535),
#   ('n03538406', 'horse_cart', 0.092085764),
#   ('n03967562', 'plow', 0.017240232),
#   ('n03124170', 'cowboy_hat', 0.010698552),
#   ('n04049303', 'rain_barrel', 0.010435037)]]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FD495496160>

# %%
def files_from_dir(a_dir):
    onlyfiles = [f for f in os.listdir(a_dir) if os.path.isfile(os.path.join(a_dir, f))]
    return onlyfiles

# %%
this_dir = '/home/tyler/Desktop/tcav_on_azure/concepts/horse_sub_1'
imgs = files_from_dir(this_dir)

# %%
img_path = os.path.join(this_dir,imgs[2])

# %%
# Horse prediction
img = image.load_img(img_path, target_size=(299, 299))
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FD4954D0358>

# %%
from keras.applications.inception_v3 import preprocess_input

img_array = np.array(img)
x = np.expand_dims(img_array, axis=0)
x = preprocess_input(x)

pred = mymodel.get_predictions(x)
decode_predictions(pred, top=5)
# Out:
# [[('n01744401', 'rock_python', 0.41688702),
#   ('n01740131', 'night_snake', 0.22719923),
#   ('n01729322', 'hognose_snake', 0.14873463),
#   ('n01751748', 'sea_snake', 0.06500338),
#   ('n01737021', 'water_snake', 0.050590847)]]

# %%
## Perturb horse activations

# %%
filename = img_path

shape = (299,299)

img = np.array(PIL.Image.open(tf.gfile.Open(filename, 'rb')).convert('RGB').resize(shape, PIL.Image.BILINEAR))
img = np.float32(img) / 255.0

acts_1 = mymodel.run_examples([img], 'mixed9')

# %%
acts_1.shape
# Out:
# (1, 8, 8, 2048)

# %%
pred = new_model.get_predictions(acts_1)
decode_predictions(pred, top=5)
# Out:
# [[('n01751748', 'sea_snake', 0.58642876),
#   ('n01740131', 'night_snake', 0.104258716),
#   ('n01744401', 'rock_python', 0.08478935),
#   ('n01737021', 'water_snake', 0.07812871),
#   ('n01729322', 'hognose_snake', 0.020191545)]]

# %%
## Get CAV
working_dir = '/home/tyler/Desktop/tcav_on_azure'
subpath = 'striped_sub_1-random500_0-mixed9'
cav_path = 'cavs/' + subpath + '-linear-0.1.pkl'
path = os.path.join(working_dir, cav_path)

this_cav = cav.CAV.load_cav(path)

perturbed_act = this_cav.perturb_act(acts_1,'striped_sub_1',alpha = 20)

# %%
perturbed_act[0][0][0]
# Out:
# array([-0.47168261,  0.        , -0.33739523, ...,  0.        ,
#         1.11533005,  0.        ])

# %%
#perturbed_act
pred = new_model.get_predictions(perturbed_act)

#pred = mymodel.get_predictions(x)
decode_predictions(pred, top=100)
# Out:
# [[('n02391049', 'zebra', 0.56864434),
#   ('n01751748', 'sea_snake', 0.057790164),
#   ('n01744401', 'rock_python', 0.02099161),
#   ('n01737021', 'water_snake', 0.019440774),
#   ('n02085620', 'Chihuahua', 0.016850617),
#   ('n01924916', 'flatworm', 0.015738912),
#   ('n03014705', 'chest', 0.01177068),
#   ('n03291819', 'envelope', 0.007167278),
#   ('n04033901', 'quill', 0.0057612723),
#   ('n02110806', 'basenji', 0.00442999),
#   ('n02107312', 'miniature_pinscher', 0.0044156807),
#   ('n01729322', 'hognose_snake', 0.0042760544),
#   ('n03447447', 'gondola', 0.00417383),
#   ('n01740131', 'night_snake', 0.003706275),
#   ('n02643566', 'lionfish', 0.0036837822),
#   ('n03950228', 'pitcher', 0.0036402),
#   ('n04229816', 'ski_mask', 0.0036118906),
#   ('n02094114', 'Norfolk_terrier', 0.003574536),
#   ('n02966193', 'carousel', 0.0029326987),
#   ('n01735189', 'garter_snake', 0.0028454256),
#   ('n02526121', 'eel', 0.0028007647),
#   ('n03223299', 'doormat', 0.0025672787),
#   ('n02808304', 'bath_towel', 0.002476462),
#   ('n02130308', 'cheetah', 0.0023842354),
#   ('n02834397', 'bib', 0.0022761668),
#   ('n01675722', 'banded_gecko', 0.0021292989),
#   ('n01806567', 'quail', 0.002053016),
#   ('n02051845', 'pelican', 0.00201137),
#   ('n04033995', 'quilt', 0.0017320573),
#   ('n02129604', 'tiger', 0.0017028851),
#   ('n02110341', 'dalmatian', 0.0016980104),
#   ('n02395406', 'hog', 0.001685613),
#   ('n03041632', 'cleaver', 0.001673084),
#   ('n02104365', 'schipperke', 0.0015816726),
#   ('n03584829', 'iron', 0.0015490329),
#   ('n04505470', 'typewriter_keyboard', 0.0015306298),
#   ('n01518878', 'ostrich', 0.0015133978),
#   ('n01494475', 'hammerhead', 0.0014674119),
#   ('n01698640', 'American_alligator', 0.0014431113),
#   ('n02490219', 'marmoset', 0.0013662302),
#   ('n02086910', 'papillon', 0.0013336412),
#   ('n02097658', 'silky_terrier', 0.0013320836),
#   ('n01950731', 'sea_slug', 0.0013053679),
#   ('n02106550', 'Rottweiler', 0.0013038667),
#   ('n03476991', 'hair_spray', 0.00130135),
#   ('n02123159', 'tiger_cat', 0.0012841577),
#   ('n01734418', 'king_snake', 0.0012820042),
#   ('n02099267', 'flat-coated_retriever', 0.0012607855),
#   ('n02107908', 'Appenzeller', 0.0012600949),
#   ('n01514859', 'hen', 0.0012424113),
#   ('n01491361', 'tiger_shark', 0.0011802202),
#   ('n03930630', 'pickup', 0.0011619015),
#   ('n01632777', 'axolotl', 0.0011288155),
#   ('n03125729', 'cradle', 0.0010998391),
#   ('n02128385', 'leopard', 0.0010993887),
#   ('n01768244', 'trilobite', 0.0010938251),
#   ('n03956157', 'planetarium', 0.0010869671),
#   ('n02099712', 'Labrador_retriever', 0.0010526289),
#   ('n03887697', 'paper_towel', 0.0010486905),
#   ('n03452741', 'grand_piano', 0.0010459733),
#   ('n02939185', 'caldron', 0.0010351556),
#   ('n04209239', 'shower_curtain', 0.0010267576),
#   ('n02807133', 'bathing_cap', 0.0010130942),
#   ('n02279972', 'monarch', 0.000975717),
#   ('n04118538', 'rugby_ball', 0.00096045615),
#   ('n02104029', 'kuvasz', 0.0009184808),
#   ('n04435653', 'tile_roof', 0.00091172784),
#   ('n15075141', 'toilet_tissue', 0.0009092237),
#   ('n04560804', 'water_jug', 0.0009088258),
#   ('n03255030', 'dumbbell', 0.00089803035),
#   ('n01910747', 'jellyfish', 0.00089568546),
#   ('n04548362', 'wallet', 0.0008934976),
#   ('n02113624', 'toy_poodle', 0.00087721326),
#   ('n03710721', 'maillot', 0.0008724365),
#   ('n01798484', 'prairie_chicken', 0.00085439807),
#   ('n02093991', 'Irish_terrier', 0.00081252307),
#   ('n01755581', 'diamondback', 0.000805385),
#   ('n03347037', 'fire_screen', 0.00079795724),
#   ('n04141076', 'sax', 0.00079775334),
#   ('n02087046', 'toy_terrier', 0.00077578577),
#   ('n02110958', 'pug', 0.0007721008),
#   ('n01669191', 'box_turtle', 0.0007717872),
#   ('n04525038', 'velvet', 0.00076620845),
#   ('n02190166', 'fly', 0.0007626916),
#   ('n01968897', 'chambered_nautilus', 0.00073966535),
#   ('n02443484', 'black-footed_ferret', 0.0007349171),
#   ('n02606052', 'rock_beauty', 0.00073408004),
#   ('n02445715', 'skunk', 0.0007273657),
#   ('n01742172', 'boa_constrictor', 0.00072681997),
#   ('n07614500', 'ice_cream', 0.00072382763),
#   ('n01616318', 'vulture', 0.0007228632),
#   ('n02128925', 'jaguar', 0.0007185918),
#   ('n07871810', 'meat_loaf', 0.0007149985),
#   ('n01641577', 'bullfrog', 0.00071444636),
#   ('n01530575', 'brambling', 0.0007129602),
#   ('n04493381', 'tub', 0.0007106044),
#   ('n04258138', 'solar_dish', 0.0007020022),
#   ('n02090721', 'Irish_wolfhound', 0.0006999966),
#   ('n02002556', 'white_stork', 0.0006994531),
#   ('n03908618', 'pencil_box', 0.0006921991)]]

# %%
acts['suit']['mixed10'][0].shape
# Out:
# (8, 8, 2048)

# %%
acts['suit']['mixed10'][0].shape
# Out:
# (8, 8, 2048)

# %%
a = acts['suit']['mixed10'][0]
a_flat = np.reshape(a, -1)
a_flat = a_flat.reshape(-1,1)

b = acts['suit']['mixed10'][1]
b_flat = np.reshape(b, -1)
b_flat = b_flat.reshape(-1,1)

# %%
np.reshape(a, -1).reshape(-1,1)

# %%
b_flat.shape
# Out:
# (131072, 1)

# %%
cosine_similarity(a_flat,b_flat)
# Out:
# array([0.36934394], dtype=float32)

# %%
this_cav.cavs[0].shape
# Out:
# (131072,)

# %%
cav_1 = this_cav.cavs[0]
cav_1 = cav_1.reshape(-1,1)

# %%
cav_1.shape
# Out:
# (131072, 1)

# %%
cosine_similarity(acts_shaped,cav_1)
# Out:
# array([0.0373991])

# %%
## Using deriv

# %%
mytcav = tcav.TCAV(sess,target, concepts, bottlenecks,
        act_generator, alphas,cav_dir = cav_dir,num_random_exp=1)

# %%
this_cav.get_key()

# %%
deriv = mytcav.get_directional_dir(
mymodel,
'zebra',
'striped_sub_1',
this_cav,
act_zebra
)

# %%
len(deriv)

# %%
this_d = {}

idx = 0
for d in deriv:
    this_d[idx] = d
    idx += 1

sorted_d = sorted(this_d.items(), key=operator.itemgetter(1),reverse=True)

# %%
#source_dir = '/Users/tyler/Desktop/dissertation/programming/tcav/cavs/'
path = 'files/f_used_10.pkl'
with open(path, 'rb') as f:
    data = pickle.load(f)
    
image_list = data

# %%
#this_d

# %%
len(sorted_d)

# %%
rank = 23

img_path = image_list[sorted_d[rank][0]]
img = image.load_img(img_path, target_size=(299, 299))

# %%
img

# %%
#sorted_d

# %%
xx = 2
top = images[sorted_d[0][0]]
bottom = images[sorted_d[xx][0]]
this_img = bottom
#this_img = top

# %%
this_img

# %%
img_path = source_images + this_img
img = image.load_img(img_path, target_size=(299, 299))

# %%
img

# %% [markdown]
# ## Load filenames

# %%
#image_list

# %%
len(image_list)

# %%
#sorted_d

# %%
xx = 3
bottom = image_list[sorted_d[xx][0]]
this_img = bottom

img_path = this_img
img = image.load_img(img_path, target_size=(299, 299))

img

# %%
class_acts = acts
for i in range(len(class_acts)):
    print(i)
    act = np.expand_dims(class_acts[i], 0)

# %%
working_dir = '/Users/tyler/Desktop/dissertation/programming/tcav'
activation_dir =  working_dir + '/activations/'
cav_dir = working_dir + '/cavs/'
source_dir = working_dir + '/concepts'

target = 'zebra'
concepts = ['striped'] 
concepts = ['dotted']   

bottlenecks = ['mixed8']


alphas = [0.1]

# %%
activation_dir =  working_dir + '/activations/acts_zebra_mixed9'


with open(activation_dir, 'rb') as f:
    x = np.load(f)
    #data = pickle.load(f)

# %%
x.shape

# %%
#acts

# %%
def cos_sim(a,b):
    return np.dot(a, b)/(norm(a)*norm(b))
